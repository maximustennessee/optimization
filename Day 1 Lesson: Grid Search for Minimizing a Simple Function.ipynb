# %%
# %pip install numpy matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 38.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 42.5 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Define the Function
# Create a function in Python to represent 𝑓(𝑥):

# %%
def f(x):
    
    return (x-3) ** 2 + 5

# %% [markdown]
# Create a range of x values

# %%
import numpy as np

x_values = np.arange(0, 6.1, 0.1)  # Generates values from 0 to 6 (inclusive) in steps of 0.1

# %% [markdown]
# Evaluate the Function and Find the Minimum

# %%
best_x = None
best_value = float('inf')

for x in x_values:
    current_value = f(x)
    if current_value < best_value:
        best_x = x
        best_value = current_value

print("Minimum x = {} & minimum f(x) = {}".format(best_x, best_value))
# Out:
# Minimum x = 3.0 & minimum f(x) = 5.0

# %% [markdown]
# Plot the Function

# %%
import matplotlib.pyplot as plt

# Evaluate f(x) for all x values for plotting
y_values = [f(x) for x in x_values]

plt.figure(figsize=(8, 4))
plt.plot(x_values, y_values, label=f'f(x) = {best_value:.2f}')
plt.scatter(best_x, best_value, color='red', label=f'Minimum at x={best_x:.2f}')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Minimizing f(x) using Grid Search')
plt.legend()
plt.grid(True)
plt.show()
